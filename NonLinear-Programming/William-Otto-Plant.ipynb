# %%
using JuMP, Ipopt, Printf, Plots
using TestImages, Images, QuartzImageIO, ImageView

# %%
img = load("tec-logo.jpg")
# Out:
# 126×472 Array{RGB4{N0f8},2} with eltype RGB4{Normed{UInt8,8}}:
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
# ...

# %%
img = load("fig3_wo.png")
# Out:
# 944×1588 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
# ...

# %%
img = load("fig1_wo.png")
# Out:
# 828×1506 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  ⋮                            ⋱  ⋮
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
# ...

# %%
img = load("fig4_wo.png")
# Out:
# 1082×1512 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
# ...

# %%
img = load("fig5_wo.png")
# Out:
# 882×1354 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
# ...

# %%
img = load("fig6_wo.png")
# Out:
# 892×1546 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  ⋮                            ⋱  ⋮
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
# ...

# %%
img = load("fig2_wo.png")
# Out:
# 736×1608 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.6,0.6,0.6,1.0)
# ...
